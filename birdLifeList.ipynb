# %%
birds = [
    "Aalscholver",
    "Baardman",
    "Bergeend",
    "Blauwborst",
    "Blauwe Kiekendief",
    "Blauwe Reiger",
    "Boerenzwaluw",
    "Bonte Vliegenvanger",
    "Booklever",
    "Boomkruiper",
    "Boomleeuwerik",
    "Boompieper",
    "Boomvalk",
    "Bruine Kiekendief",
    "Buizerd",
    "Dodaars",
    "Drieteenstrandloper",
    "Ekstr",
    "Fazant",
    "Fitis",
    "Fuut",
    "Gaai",
    "Gierzwaluw",
    "Glanskop",
    "Graspieper",
    "Grauwe Gans",
    "Grauwe Vliegenvanger",
    "Grote Bonte Specht",
    "Grote Canadese Gans",
    "Grote Lijster",
    "Grote Stern",
    "Grote Zilverreiger",
    "Grutto",
    "Halsbandparkiet",
    "Heggenmus",
    "Houtduif",
    "Huisnus",
    "Huiszwaluw",
    "IJsvogel",
    "Kauw",
    "Kievit",
    "Kleine Karekiet",
    "Kleine Mantelmeeuw",
    "Kleine Zilverreiger",
    "Kneu",
    "Knobbelzwaan",
    "Koekoek",
    "Kokmeeuw",
    "Koolmees",
    "Koperwiek",
    "Krakeend",
    "Kuifeend",
    "Kuifmees",
    "Lachtstern",
    "Lepelaar",
    "Mandarijneend",
    "Meerkout",
    "Merel",
    "Middelste Bonte Specht",
    "Nijlgans",
    "Ooievaar",
    "Pimpelmees",
    "Poelruiter",
    "Purperreiger",
    "Putter",
    "Rietgors",
    "Rietzanger",
    "Roerdomp",
    "Roodborst",
    "Roodborsttapuit",
    "Rosse Grutto",
    "Rotgans",
    "Scholekster",
    "Slechtvalk",
    "Slobeend",
    "Smient",
    "Soepeend",
    "Sperwer",
    "Spreeuw",
    "Staartmees",
    "Stadsduif",
    "Tjiftjaf",
    "Torenvalk",
    "Tuinfluiter",
    "Veldleeuwerik",
    "Vink",
    "Vuurgoudhaan",
    "Waterhoen",
    "Wespendief",
    "Wilde Eend",
    "Winterkoning",
    "Wintertaling",
    "Witte Kwikstaart",
    "Zanglijster",
    "Zeearend",
    "Zilvermeeuw",
    "Zwarte Kraai",
    "Zwarte Mees",
    "Zwarte Specht",
    "Zwarte Stern",
    "Zwartkop"
]

# %%
for i in birds:
    print("This bird is called: ",i,"!")
# Out:
# This bird is called:  Aalscholver !
# This bird is called:  Baardman !
# This bird is called:  Bergeend !
# This bird is called:  Blauwborst !
# This bird is called:  Blauwe Kiekendief !
# This bird is called:  Blauwe Reiger !
# This bird is called:  Boerenzwaluw !
# This bird is called:  Bonte Vliegenvanger !
# This bird is called:  Booklever !
# This bird is called:  Boomkruiper !
# This bird is called:  Boomleeuwerik !
# This bird is called:  Boompieper !
# This bird is called:  Boomvalk !
# This bird is called:  Bruine Kiekendief !
# This bird is called:  Buizerd !
# This bird is called:  Dodaars !
# This bird is called:  Drieteenstrandloper !
# This bird is called:  Ekstr !
# This bird is called:  Fazant !
# This bird is called:  Fitis !
# This bird is called:  Fuut !
# This bird is called:  Gaai !
# This bird is called:  Gierzwaluw !
# This bird is called:  Glanskop !
# This bird is called:  Graspieper !
# This bird is called:  Grauwe Gans !
# ...

# %%
html = f"""            <li class="bird" style="background: url(img/birds/{bird}.jpg) no-repeat center; background-size: cover;">
                <div class="birdInfoItem">
                    <div>
                        <p class="caption">{bird}</p>
                    </div>
                </div>
            </li>
"""

# %%
print(html)
# Out:
#             <li class="bird" style="background: url(img/birds/testtesttest.jpg) no-repeat center; background-size: cover;">
#                 <div class="birdInfoItem">
#                     <div>
#                         <p class="caption">testtesttest</p>
#                     </div>
#                 </div>
#             </li>

# %%
for i in birds:
    bird = i
    print(f"""            <li class="bird" style="background: url(img/birds/{bird}.jpg) no-repeat center; background-size: cover;">
                <div class="birdInfoItem">
                    <div>
                        <p class="caption">{bird}</p>
                    </div>
                </div>
            </li>
""")
# Out:
#             <li class="bird" style="background: url(img/birds/Aalscholver.jpg) no-repeat center; background-size: cover;">
#                 <div class="birdInfoItem">
#                     <div>
#                         <p class="caption">Aalscholver</p>
#                     </div>
#                 </div>
#             </li>
#
#             <li class="bird" style="background: url(img/birds/Baardman.jpg) no-repeat center; background-size: cover;">
#                 <div class="birdInfoItem">
#                     <div>
#                         <p class="caption">Baardman</p>
#                     </div>
#                 </div>
#             </li>
#
#             <li class="bird" style="background: url(img/birds/Bergeend.jpg) no-repeat center; background-size: cover;">
#                 <div class="birdInfoItem">
#                     <div>
#                         <p class="caption">Bergeend</p>
#                     </div>
#                 </div>
#             </li>
#
# ...
